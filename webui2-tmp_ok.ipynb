# %% [markdown]
# このスクリプトについてのサポート、Stable Diffusion Web UI に関するサポート、および Paperspace に関するサポートについては https://bit.ly/paperspace-openchat に参加してみてください。LINE のオープンチャットです(LINEのメインアカウントの存在および本名がバレることはありません)。よろしくお願いします。

# %%
#(0) 初回のみ ... stable-diffusion-webui-forgeのダウンロード
# %cd /notebooks
# !rm -rf stable-diffusion-webui-forge
# !git clone https://github.com/lllyasviel/stable-diffusion-webui-forge.git
# Out:
# /notebooks
# Cloning into 'stable-diffusion-webui-forge'...
# remote: Enumerating objects: 37893, done.
# remote: Counting objects: 100% (2734/2734), done.
# remote: Compressing objects: 100% (803/803), done.
# remote: Total 37893 (delta 2030), reused 2467 (delta 1888), pack-reused 35159
# Receiving objects: 100% (37893/37893), 43.94 MiB | 24.37 MiB/s, done.
# Resolving deltas: 100% (25931/25931), done.
# Updating files: 100% (1360/1360), done.

# %%
##(1) 起動毎にいつも
# フォルダを準備
# %mkdir -p /tmp/SD/{models,embeddings}
# %mkdir -p /tmp/SDXL/{models,embeddings}

## モデルのダウンロード
# %cd /tmp/SD/models
#実写系
# !wget -nc "https://cdn-lfs.huggingface.co/repos/d1/de/d1de2c192076dcdb212048d179a6ab5ee52ed6902d5d58ceb8326bac77eb64ef/61f21f591509874728f30685f93c0668f016128adf87e9ec5cab752914387cbd?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors%3B+filename%3D%22abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors%22%3B&Expires=1712497099&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=z4HL%7E2UHZTI%7EHn4WTQH%7EylfzGDzTJmslIr%7EbBnoGdegxqe-3b9XO8mQbLjAALye6vOgA1jbJ6n5CToU-IXmbCDiZP3EgKvCLsSQFihDeICPz5E2oYeMxsgJ5UuMAOuUa6PI0wgpFNA2GgORqMUTroJ2wRlaRLyuzRvcLEkslg4RRiFdac5Pr8p9eOLopg-EIsYh13ldfktJBiWRSKIgGbNBW46BCAfOypHyGNycZ1NTJnYh5h-LJxs8YdiOWJZZeQbIPXH2a89DlSgQIhosx3Zz3nTZ%7E6yeQNJCjDVgkadRwujFl0wOoBueq7BnbSfISf3V0IE0amE31DzlWzSzkqw__&Key-Pair-Id=KVTP0A1DKRTAX" -O abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors
# !wget -nc https://civitai.com/api/download/models/11745  -O chilloutmix_NiPrunedFp32Fix.safetensors
# !wget -nc https://civitai.com/api/download/models/220737 -O galenaREDUX_v30.safetensors
# !wget -nc "https://civitai.com/api/download/models/106922?type=Model&format=SafeTensor&size=pruned&fp=fp16" -O hassakuHentaiModel_v13.safetensors
# !wget -nc https://civitai.com/api/download/models/334282 -O kawaiiRealisticAsian_v07.safetensors
# !wget -nc https://civitai.com/api/download/models/87825  -O kizukiAnimeHentai_animeHentaiV3.safetensors
# !wget -nc "https://civitai.com/api/download/models/287641?type=Model&format=SafeTensor&size=pruned&fp=fp16" -O meichidarkMix_meichidarkV5.safetensors
# !wget -nc "https://civitai.com/api/download/models/100675?type=Model&format=SafeTensor&size=pruned&fp=fp16" -O meinahentai_v4.safetensors
# !wget -nc https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/67578/perfect20world20v6.cmkV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22perfectWorld_v6Baked.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240404/us-east-1/s3/aws4_request&X-Amz-Date=20240404T114150Z&X-Amz-SignedHeaders=host&X-Amz-Signature=c8641c502a1fa5bdd1bb20d24add0552008792c635fefd0b36dbafb00d447d25 -O perfectWorld_v6Baked.safetensors

## embeddingsのダウンロード
# %cd /tmp/SD/embeddings
# !wget -nc https://civitai.com/api/download/models/125849 -O bad-hands-5.pt
# !wget -nc "https://civitai.com/api/download/models/9208?type=Model&format=SafeTensor&size=full&fp=fp16" -O easynegative.safetensors
# !wget -nc https://civitai.com/api/download/models/60938 -O negative_hand-neg.pt
# !wget -nc "https://civitai.com/api/download/models/5637?type=Model&format=PickleTensor&size=full&fp=fp16" -O ng_deepnegative_v1_75t.pt
# Out:
# /tmp/SD/models
# --2024-04-05 09:47:26--  https://cdn-lfs.huggingface.co/repos/d1/de/d1de2c192076dcdb212048d179a6ab5ee52ed6902d5d58ceb8326bac77eb64ef/61f21f591509874728f30685f93c0668f016128adf87e9ec5cab752914387cbd?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors%3B+filename%3D%22abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors%22%3B&Expires=1712497099&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=z4HL%7E2UHZTI%7EHn4WTQH%7EylfzGDzTJmslIr%7EbBnoGdegxqe-3b9XO8mQbLjAALye6vOgA1jbJ6n5CToU-IXmbCDiZP3EgKvCLsSQFihDeICPz5E2oYeMxsgJ5UuMAOuUa6PI0wgpFNA2GgORqMUTroJ2wRlaRLyuzRvcLEkslg4RRiFdac5Pr8p9eOLopg-EIsYh13ldfktJBiWRSKIgGbNBW46BCAfOypHyGNycZ1NTJnYh5h-LJxs8YdiOWJZZeQbIPXH2a89DlSgQIhosx3Zz3nTZ%7E6yeQNJCjDVgkadRwujFl0wOoBueq7BnbSfISf3V0IE0amE31DzlWzSzkqw__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.111, 18.164.116.15, 18.164.116.106, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5570804089 (5.2G) [binary/octet-stream]
# Saving to: ‘abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors’
#
# abyssorangemix2NSFW 100%[===================>]   5.19G  51.0MB/s    in 1m 48s
#
# 2024-04-05 09:49:14 (49.2 MB/s) - ‘abyssorangemix2NSFW_abyssorangemix2Nsfw.safetensors’ saved [5570804089/5570804089]
#
# --2024-04-05 09:49:15--  https://civitai.com/api/download/models/11745
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/76164/model/chilloutmixNiPruned.Tw1O.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22chilloutmix_NiPrunedFp32Fix.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T094915Z&X-Amz-SignedHeaders=host&X-Amz-Signature=7b691e6e91b2b8c895d51e1a299cd34a246b4c157433a39744b9230e6d6dab76 [following]
# --2024-04-05 09:49:16--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/76164/model/chilloutmixNiPruned.Tw1O.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22chilloutmix_NiPrunedFp32Fix.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T094915Z&X-Amz-SignedHeaders=host&X-Amz-Signature=7b691e6e91b2b8c895d51e1a299cd34a246b4c157433a39744b9230e6d6dab76
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4265097179 (4.0G) [application/octet-stream]
# Saving to: ‘chilloutmix_NiPrunedFp32Fix.safetensors’
#
# chilloutmix_NiPrune 100%[===================>]   3.97G  36.6MB/s    in 1m 40s
#
# 2024-04-05 09:50:56 (40.5 MB/s) - ‘chilloutmix_NiPrunedFp32Fix.safetensors’ saved [4265097179/4265097179]
#
# --2024-04-05 09:50:57--  https://civitai.com/api/download/models/220737
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/10924/galena20REDUX203.MWFV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22galenaREDUX_v30.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T095057Z&X-Amz-SignedHeaders=host&X-Amz-Signature=b4a8d78c945baf9a7b02a4ec3aadc3e180ca0a8965145d9217b516a601d20c2c [following]
# --2024-04-05 09:50:57--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/10924/galena20REDUX203.MWFV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22galenaREDUX_v30.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T095057Z&X-Amz-SignedHeaders=host&X-Amz-Signature=b4a8d78c945baf9a7b02a4ec3aadc3e180ca0a8965145d9217b516a601d20c2c
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132651178 (2.0G) [application/octet-stream]
# Saving to: ‘galenaREDUX_v30.safetensors’
#
# galenaREDUX_v30.saf 100%[===================>]   1.99G  3.78MB/s    in 12m 7s
#
# 2024-04-05 10:03:05 (2.80 MB/s) - ‘galenaREDUX_v30.safetensors’ saved [2132651178/2132651178]
#
# --2024-04-05 10:03:05--  https://civitai.com/api/download/models/106922?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/39650/model/hassakuv13.XBYY.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22hassakuHentaiModel_v13.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T100305Z&X-Amz-SignedHeaders=host&X-Amz-Signature=83ae85bc68bcba64fda582908f6a21cc65e87866459ba1f1b62fbe7ffc147317 [following]
# --2024-04-05 10:03:05--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/39650/model/hassakuv13.XBYY.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22hassakuHentaiModel_v13.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T100305Z&X-Amz-SignedHeaders=host&X-Amz-Signature=83ae85bc68bcba64fda582908f6a21cc65e87866459ba1f1b62fbe7ffc147317
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132625894 (2.0G) [application/octet-stream]
# Saving to: ‘hassakuHentaiModel_v13.safetensors’
#
# hassakuHentaiModel_ 100%[===================>]   1.99G  27.0MB/s    in 49s
#
# 2024-04-05 10:03:55 (41.2 MB/s) - ‘hassakuHentaiModel_v13.safetensors’ saved [2132625894/2132625894]
#
# --2024-04-05 10:03:55--  https://civitai.com/api/download/models/334282
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1769303/kawaiirealisticasianmi.rMHk.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kawaiiRealisticAsian_v07.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T100356Z&X-Amz-SignedHeaders=host&X-Amz-Signature=925850fa98b997972ea30694cc8a8cd39ea637b2218eab2075369de79f741da2 [following]
# --2024-04-05 10:03:56--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1769303/kawaiirealisticasianmi.rMHk.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kawaiiRealisticAsian_v07.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T100356Z&X-Amz-SignedHeaders=host&X-Amz-Signature=925850fa98b997972ea30694cc8a8cd39ea637b2218eab2075369de79f741da2
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132626066 (2.0G)
# Saving to: ‘kawaiiRealisticAsian_v07.safetensors’
#
# kawaiiRealisticAsia 100%[===================>]   1.99G  3.48MB/s    in 11m 10s
#
# 2024-04-05 10:15:06 (3.04 MB/s) - ‘kawaiiRealisticAsian_v07.safetensors’ saved [2132626066/2132626066]
#
# --2024-04-05 10:15:07--  https://civitai.com/api/download/models/87825
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/907398/kizuki2020anime20civitai.JEfv.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kizukiAnimeHentai_animeHentaiV3.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101507Z&X-Amz-SignedHeaders=host&X-Amz-Signature=ba6a46f95fbcffb805295fe50a6872d44ba40bf40069f6d3c492b02745ff5387 [following]
# --2024-04-05 10:15:07--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/907398/kizuki2020anime20civitai.JEfv.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kizukiAnimeHentai_animeHentaiV3.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101507Z&X-Amz-SignedHeaders=host&X-Amz-Signature=ba6a46f95fbcffb805295fe50a6872d44ba40bf40069f6d3c492b02745ff5387
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132626066 (2.0G)
# Saving to: ‘kizukiAnimeHentai_animeHentaiV3.safetensors’
#
# kizukiAnimeHentai_a 100%[===================>]   1.99G   109MB/s    in 22s
#
# 2024-04-05 10:15:29 (93.9 MB/s) - ‘kizukiAnimeHentai_animeHentaiV3.safetensors’ saved [2132626066/2132626066]
#
# --2024-04-05 10:15:30--  https://civitai.com/api/download/models/287641?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1120820/meichiDarkEpic.oEON.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22meichidarkMix_meichidarkV5.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101530Z&X-Amz-SignedHeaders=host&X-Amz-Signature=b45830c43b3c4e1e46c260ff21ebee088c0938bc25c7fc6f3e3154f4bb73b674 [following]
# --2024-04-05 10:15:30--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1120820/meichiDarkEpic.oEON.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22meichidarkMix_meichidarkV5.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101530Z&X-Amz-SignedHeaders=host&X-Amz-Signature=b45830c43b3c4e1e46c260ff21ebee088c0938bc25c7fc6f3e3154f4bb73b674
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5401426744 (5.0G)
# Saving to: ‘meichidarkMix_meichidarkV5.safetensors’
#
# meichidarkMix_meich 100%[===================>]   5.03G  39.9MB/s    in 2m 27s
#
# 2024-04-05 10:17:57 (35.1 MB/s) - ‘meichidarkMix_meichidarkV5.safetensors’ saved [5401426744/5401426744]
#
# --2024-04-05 10:17:58--  https://civitai.com/api/download/models/100675?type=Model&format=SafeTensor&size=pruned&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/141871/model/meinahentai20V4.g5SV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22meinahentai_v4.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101758Z&X-Amz-SignedHeaders=host&X-Amz-Signature=c586405d6398c6e6d8d283d7c37368f7a0978955d5c65a6b199ce1b14447e103 [following]
# --2024-04-05 10:17:58--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/141871/model/meinahentai20V4.g5SV.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22meinahentai_v4.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101758Z&X-Amz-SignedHeaders=host&X-Amz-Signature=c586405d6398c6e6d8d283d7c37368f7a0978955d5c65a6b199ce1b14447e103
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132651874 (2.0G) [application/octet-stream]
# Saving to: ‘meinahentai_v4.safetensors’
#
# meinahentai_v4.safe 100%[===================>]   1.99G  83.7MB/s    in 22s
#
# 2024-04-05 10:18:21 (92.5 MB/s) - ‘meinahentai_v4.safetensors’ saved [2132651874/2132651874]
#
# /bin/bash: response-content-disposition=attachment%3B%20filename%3D%22perfectWorld_v6Baked.safetensors%22: command not found
# /bin/bash: X-Amz-Algorithm=AWS4-HMAC-SHA256: command not found
# /bin/bash: X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240404/us-east-1/s3/aws4_request: No such file or directory
# /bin/bash: X-Amz-Date=20240404T114150Z: command not found
# /bin/bash: X-Amz-SignedHeaders=host: command not found
# /bin/bash: X-Amz-Signature=c8641c502a1fa5bdd1bb20d24add0552008792c635fefd0b36dbafb00d447d25: command not found
# /tmp/SD/embeddings
# --2024-04-05 10:18:21--  https://civitai.com/api/download/models/125849
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/642113/model/badHands5.ZPLc.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22bad-hands-5.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101822Z&X-Amz-SignedHeaders=host&X-Amz-Signature=48e66e066d37968b3ff443a05056656bfa531abdebc280e34acbb73750fafbc1 [following]
# --2024-04-05 10:18:22--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/642113/model/badHands5.ZPLc.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22bad-hands-5.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101822Z&X-Amz-SignedHeaders=host&X-Amz-Signature=48e66e066d37968b3ff443a05056656bfa531abdebc280e34acbb73750fafbc1
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7083 (6.9K) [application/octet-stream]
# Saving to: ‘bad-hands-5.pt’
#
# bad-hands-5.pt      100%[===================>]   6.92K  --.-KB/s    in 0s
#
# 2024-04-05 10:18:22 (57.2 MB/s) - ‘bad-hands-5.pt’ saved [7083/7083]
#
# --2024-04-05 10:18:22--  https://civitai.com/api/download/models/9208?type=Model&format=SafeTensor&size=full&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/3068/model/easynegative.YTMh.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22easynegative.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101823Z&X-Amz-SignedHeaders=host&X-Amz-Signature=6f00ba1657a674ea4956d23bc00a34a5b2a618a6abaffffc4106a1061a6e15e2 [following]
# --2024-04-05 10:18:23--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/3068/model/easynegative.YTMh.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22easynegative.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101823Z&X-Amz-SignedHeaders=host&X-Amz-Signature=6f00ba1657a674ea4956d23bc00a34a5b2a618a6abaffffc4106a1061a6e15e2
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24655 (24K) [application/octet-stream]
# Saving to: ‘easynegative.safetensors’
#
# easynegative.safete 100%[===================>]  24.08K  --.-KB/s    in 0s
#
# 2024-04-05 10:18:23 (68.9 MB/s) - ‘easynegative.safetensors’ saved [24655/24655]
#
# --2024-04-05 10:18:23--  https://civitai.com/api/download/models/60938
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/162020/default/negativeHand.iVCT.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22negative_hand-neg.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101824Z&X-Amz-SignedHeaders=host&X-Amz-Signature=4960ebb2650d03b9ccfd3b49eb48c6613a00540ab5351adb7be136192a2d83db [following]
# --2024-04-05 10:18:24--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/162020/default/negativeHand.iVCT.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22negative_hand-neg.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101824Z&X-Amz-SignedHeaders=host&X-Amz-Signature=4960ebb2650d03b9ccfd3b49eb48c6613a00540ab5351adb7be136192a2d83db
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25533 (25K) [application/octet-stream]
# Saving to: ‘negative_hand-neg.pt’
#
# negative_hand-neg.p 100%[===================>]  24.93K  --.-KB/s    in 0.002s
#
# 2024-04-05 10:18:24 (14.0 MB/s) - ‘negative_hand-neg.pt’ saved [25533/25533]
#
# --2024-04-05 10:18:25--  https://civitai.com/api/download/models/5637?type=Model&format=PickleTensor&size=full&fp=fp16
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/23676/model/ngDeepnegativeV175T.F2ns.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22ng_deepnegative_v1_75t.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101825Z&X-Amz-SignedHeaders=host&X-Amz-Signature=d98ae0caea4931cdf978c4fb8ff185e5d02509357fb9e37febb0aed98f7f2915 [following]
# --2024-04-05 10:18:25--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/23676/model/ngDeepnegativeV175T.F2ns.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22ng_deepnegative_v1_75t.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240405/us-east-1/s3/aws4_request&X-Amz-Date=20240405T101825Z&X-Amz-SignedHeaders=host&X-Amz-Signature=d98ae0caea4931cdf978c4fb8ff185e5d02509357fb9e37febb0aed98f7f2915
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 231339 (226K) [application/octet-stream]
# Saving to: ‘ng_deepnegative_v1_75t.pt’
#
# ng_deepnegative_v1_ 100%[===================>] 225.92K  --.-KB/s    in 0.005s
#
# 2024-04-05 10:18:25 (49.0 MB/s) - ‘ng_deepnegative_v1_75t.pt’ saved [231339/231339]

# %%
#(4) WebUI起動
# !apt update
# !apt -y install python3.10
# !apt -y install libpython3.10-dev
# !apt -y install build-essential
# !apt -y install ffmpeg
# !curl -sS https://bootstrap.pypa.io/get-pip.py | python3.10
# !python3.10 -m pip install torch==2.0.1+cu118 torchvision==0.15.2+cu118 torchaudio==2.0.2+cu118 torchtext==0.15.2 torchdata==0.6.1 --extra-index-url https://download.pytorch.org/whl/cu118 -U
# !python3.10 -m pip install xformers==0.0.20 triton==2.0.0 -U
# !python3.10 -m pip install httpx==0.24.1
#!python3.10 -m pip install insightface -U
# !python3.10 -m pip install matplotlib -U
# !python3.10 -m pip install ipython -U
from IPython import get_ipython
get_ipython().run_line_magic('matplotlib', 'inline')
# %cd /notebooks/stable-diffusion-webui-forge
# !python3.10 launch.py --xformers --enable-insecure-extension-access --share --gradio-queue --ckpt-dir /tmp/SD/models --embeddings-dir /tmp/SD/embeddings
# Out:
# Get:1 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1581 B]
# Get:3 https://deb.nodesource.com/node_16.x focal InRelease [4583 B]
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [1493 kB]
# Get:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease [18.1 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Get:8 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1194 kB]
# Get:9 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [3505 kB]
# Get:10 https://deb.nodesource.com/node_16.x focal/main amd64 Packages [776 B]
# Get:11 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [3442 kB]3m
# Get:12 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [29.7 kB]3m
# Get:13 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 Packages [35.5 kB]
# Get:15 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1489 kB]
# Get:16 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3980 kB]
# Get:17 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [3592 kB]
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [32.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu focal-backports/main amd64 Packages [55.2 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-backports/universe amd64 Packages [28.6 kB]
# Fetched 19.2 MB in 2s (10.2 MB/s)33m
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# 174 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.10-minimal libpython3.10-stdlib python3.10-minimal
# Suggested packages:
#   python3.10-venv binfmt-support
# The following NEW packages will be installed:
#   libpython3.10-minimal libpython3.10-stdlib python3.10 python3.10-minimal
# 0 upgraded, 4 newly installed, 0 to remove and 174 not upgraded.
# Need to get 5222 kB of archives.
# After this operation, 20.2 MB of additional disk space will be used.
# Get:1 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 libpython3.10-minimal amd64 3.10.13-1+focal1 [823 kB]
# Get:2 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal/main amd64 python3.10-minimal amd64 3.10.13-1+focal1 [2080 kB]
# 27% [2 python3.10-minimal 639 kB/2080 kB 31%]m

# %%
#(5) AUTOMATIC1111のダウンロード
# %cd /notebooks
# !rm -rf stable-diffusion-webui
# !git clone https://github.com/lllyasviel/stable-diffusion-webui-forge.git
# Out:
# /notebooks
# Cloning into 'stable-diffusion-webui-forge'...
# remote: Enumerating objects: 37893, done.
# remote: Counting objects: 100% (2734/2734), done.
# remote: Compressing objects: 100% (806/806), done.
# remote: Total 37893 (delta 2029), reused 2461 (delta 1885), pack-reused 35159
# Receiving objects: 100% (37893/37893), 43.94 MiB | 17.72 MiB/s, done.
# Resolving deltas: 100% (25930/25930), done.

# %%
#(2) モデルのダウンロード（ここにダウンロードしたいモデルを追加）
# %cd /notebooks/stable-diffusion-webui-forge/models/Stable-diffusion
# !wget -nc https://civitai.com/api/download/models/334282 -O kawaiiRealisticAsian_v07.safetensors
#!wget -nc https://civitai.com/api/download/models/16859 -O BlueberryMix-1.0.safetensors
#!wget -nc https://civitai.com/api/download/models/11745 -O Chilloutmix-Ni-pruned-fp32-fix.safetensors
#!wget -nc https://huggingface.co/sazyou-roukaku/chilled_remix/resolve/5876389637f3f82d2b33a609f85f9b36aa4748fe/chilled_remix_v1vae.safetensors -O chilled_remix_v1vae.safetensors
#!wget -nc https://huggingface.co/sazyou-roukaku/chilled_remix/resolve/main/chilled_remix_v2.safetensors -O chilled_remix_v2.safetensors

# %cd /notebooks/stable-diffusion-webui-forge/embeddings
# !wget -nc https://civitai.com/api/download/models/60938 -O negative_hand-neg.pt
# !wget -nc https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt -O bad_prompt.pt

# %cd /notebooks/stable-diffusion-webui-forge/models/VAE
# !wget -nc https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -O vae-ft-mse-840000-ema-pruned.ckpt

# !mkdir -p /notebooks/stable-diffusion-webui-forge/models/Lora
# %cd /notebooks/stable-diffusion-webui-forge/models/Lora
# !wget -nc https://civitai.com/api/download/models/54280 -O attire_hotlimit-10.safetensors
# Out:
# /notebooks/stable-diffusion-webui-forge/models/Stable-diffusion
# --2024-04-03 12:46:36--  https://civitai.com/api/download/models/334282
# Resolving civitai.com (civitai.com)... 104.18.23.206, 104.18.22.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.23.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1769303/kawaiirealisticasianmi.rMHk.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kawaiiRealisticAsian_v07.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T124636Z&X-Amz-SignedHeaders=host&X-Amz-Signature=ab87ef2075a4123b6106bccd819490cd2198d46909b6e32dd9215e0c763c2dd5 [following]
# --2024-04-03 12:46:36--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/1769303/kawaiirealisticasianmi.rMHk.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22kawaiiRealisticAsian_v07.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T124636Z&X-Amz-SignedHeaders=host&X-Amz-Signature=ab87ef2075a4123b6106bccd819490cd2198d46909b6e32dd9215e0c763c2dd5
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2132626066 (2.0G)
# Saving to: ‘kawaiiRealisticAsian_v07.safetensors’
#
# kawaiiRealisticAsia 100%[===================>]   1.99G  2.67MB/s    in 13m 3s
#
# 2024-04-03 12:59:39 (2.60 MB/s) - ‘kawaiiRealisticAsian_v07.safetensors’ saved [2132626066/2132626066]
#
# /notebooks/stable-diffusion-webui-forge/embeddings
# --2024-04-03 12:59:40--  https://civitai.com/api/download/models/60938
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:17ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/162020/default/negativeHand.iVCT.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22negative_hand-neg.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T125940Z&X-Amz-SignedHeaders=host&X-Amz-Signature=00040a8fa0dd53ed5c24e6e615c5962fd5b77ad2f76303c0fa9bec0bcd7b8a5b [following]
# --2024-04-03 12:59:40--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/162020/default/negativeHand.iVCT.pt?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22negative_hand-neg.pt%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T125940Z&X-Amz-SignedHeaders=host&X-Amz-Signature=00040a8fa0dd53ed5c24e6e615c5962fd5b77ad2f76303c0fa9bec0bcd7b8a5b
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.9.90, 104.18.8.90, 2606:4700::6812:85a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.9.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25533 (25K) [application/octet-stream]
# Saving to: ‘negative_hand-neg.pt’
#
# negative_hand-neg.p 100%[===================>]  24.93K  --.-KB/s    in 0.001s
#
# 2024-04-03 12:59:41 (40.3 MB/s) - ‘negative_hand-neg.pt’ saved [25533/25533]
#
# --2024-04-03 12:59:42--  https://huggingface.co/datasets/Nerfgun3/bad_prompt/resolve/main/bad_prompt_version2.pt
# Resolving huggingface.co (huggingface.co)... 18.238.49.112, 18.238.49.117, 18.238.49.10, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/47/59/4759ed84c4194637ed9fb073b3d05fa0968b0177dfc1d66d9e9323fecc3dbe4f/6f35e7dd816ae04bb3f774a9a17ebfbc50c0e3a53f69a9a40bed05936d3a3812?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bad_prompt_version2.pt%3B+filename%3D%22bad_prompt_version2.pt%22%3B&Expires=1712407583&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=BAhjby1q3nQ7g6gtZoZ5-TdtWldqn4TnqehPzSi7TAdjIPkn22eqHSPFjrvP7%7E0PgEngawYMH8D55nI6cQ%7EJdisDKu%7EnaDcNYa2qJtbzxoEUTx7ROCmr4vnu0sVaSo52uGI2PpG1pZz1PJxpwy5yrH0Rkp4cpoLc5Y0GuEzS-cRbh%7Esznp5qdOHxzsmo6Bz29sB%7En9x0eUDIbBauGulb0ZKHHOcKzmrnQm4lQl9Db6QLdvD7Yf-hzEaI4sYYP79QB3U2EccI2MYQidmAMYj0syciBdLJI%7EAwfzFB0IhtnSsmD8Daq-fTtDQPdiavTlK8Vjo4lXPexcMwgyy3CRs1JA__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-04-03 12:59:42--  https://cdn-lfs.huggingface.co/repos/47/59/4759ed84c4194637ed9fb073b3d05fa0968b0177dfc1d66d9e9323fecc3dbe4f/6f35e7dd816ae04bb3f774a9a17ebfbc50c0e3a53f69a9a40bed05936d3a3812?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27bad_prompt_version2.pt%3B+filename%3D%22bad_prompt_version2.pt%22%3B&Expires=1712407583&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=BAhjby1q3nQ7g6gtZoZ5-TdtWldqn4TnqehPzSi7TAdjIPkn22eqHSPFjrvP7%7E0PgEngawYMH8D55nI6cQ%7EJdisDKu%7EnaDcNYa2qJtbzxoEUTx7ROCmr4vnu0sVaSo52uGI2PpG1pZz1PJxpwy5yrH0Rkp4cpoLc5Y0GuEzS-cRbh%7Esznp5qdOHxzsmo6Bz29sB%7En9x0eUDIbBauGulb0ZKHHOcKzmrnQm4lQl9Db6QLdvD7Yf-hzEaI4sYYP79QB3U2EccI2MYQidmAMYj0syciBdLJI%7EAwfzFB0IhtnSsmD8Daq-fTtDQPdiavTlK8Vjo4lXPexcMwgyy3CRs1JA__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.173.219.34, 18.173.219.80, 18.173.219.24, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.173.219.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 25515 (25K) [binary/octet-stream]
# Saving to: ‘bad_prompt.pt’
#
# bad_prompt.pt       100%[===================>]  24.92K  --.-KB/s    in 0s
#
# 2024-04-03 12:59:42 (215 MB/s) - ‘bad_prompt.pt’ saved [25515/25515]
#
# /notebooks/stable-diffusion-webui-forge/models/VAE
# --2024-04-03 12:59:43--  https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt
# Resolving huggingface.co (huggingface.co)... 18.238.49.112, 18.238.49.117, 18.238.49.70, ...
# Connecting to huggingface.co (huggingface.co)|18.238.49.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs.huggingface.co/repos/ec/ee/eceee26c5834d8a75cf04eeb17dfc06d1d5fe1d80c2f19520b148c11e2e98c45/c6a580b13a5bc05a5e16e4dbb80608ff2ec251a162311590c1f34c013d7f3dab?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27vae-ft-mse-840000-ema-pruned.ckpt%3B+filename%3D%22vae-ft-mse-840000-ema-pruned.ckpt%22%3B&Expires=1712408383&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=uKqu3TLvtAm61iSYIIJ1ighl337p2147Ys05Yq4VuNNdl1WzNN0YP4aio8Kl4E8XabF5WslVeqmzdIzrJi21g8D0tgc6A%7ET8%7Ep9SWuU9T4JJtYHEeglr5Nx58%7EqcrhCG%7EdFlHdHcqEctKzDUfMwuwrwdYF54KlP0-e0eSyTEqPONGpCdT0ZFh9K-yMVnWnMOAk1AFD9izMEiK%7EfS9uF8bqSrq0PoX80QpT1w0Bu12i0%7Ei4-h9gTB86XgtNj7xE4zbwD1s7nn%7E%7ET2sBF%7EQzbJRgzgwtvTIO5D0cL0kTm1OxawKcNaQO3iPagKnqRxrrJoACuTwXVcEmODCWSfSPH9XQ__&Key-Pair-Id=KVTP0A1DKRTAX [following]
# --2024-04-03 12:59:43--  https://cdn-lfs.huggingface.co/repos/ec/ee/eceee26c5834d8a75cf04eeb17dfc06d1d5fe1d80c2f19520b148c11e2e98c45/c6a580b13a5bc05a5e16e4dbb80608ff2ec251a162311590c1f34c013d7f3dab?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27vae-ft-mse-840000-ema-pruned.ckpt%3B+filename%3D%22vae-ft-mse-840000-ema-pruned.ckpt%22%3B&Expires=1712408383&Policy=%7EcmVzcG9uc2UtY29udGVudC1kaXNwb3NpdGlvbj0qIn1dfQ__&Signature=uKqu3TLvtAm61iSYIIJ1ighl337p2147Ys05Yq4VuNNdl1WzNN0YP4aio8Kl4E8XabF5WslVeqmzdIzrJi21g8D0tgc6A%7ET8%7Ep9SWuU9T4JJtYHEeglr5Nx58%7EqcrhCG%7EdFlHdHcqEctKzDUfMwuwrwdYF54KlP0-e0eSyTEqPONGpCdT0ZFh9K-yMVnWnMOAk1AFD9izMEiK%7EfS9uF8bqSrq0PoX80QpT1w0Bu12i0%7Ei4-h9gTB86XgtNj7xE4zbwD1s7nn%7E%7ET2sBF%7EQzbJRgzgwtvTIO5D0cL0kTm1OxawKcNaQO3iPagKnqRxrrJoACuTwXVcEmODCWSfSPH9XQ__&Key-Pair-Id=KVTP0A1DKRTAX
# Resolving cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)... 18.164.116.15, 18.164.116.106, 18.164.116.66, ...
# Connecting to cdn-lfs.huggingface.co (cdn-lfs.huggingface.co)|18.164.116.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 334695179 (319M) [binary/octet-stream]
# Saving to: ‘vae-ft-mse-840000-ema-pruned.ckpt’
#
# vae-ft-mse-840000-e 100%[===================>] 319.19M   260MB/s    in 1.2s
#
# 2024-04-03 12:59:44 (260 MB/s) - ‘vae-ft-mse-840000-ema-pruned.ckpt’ saved [334695179/334695179]
#
# /notebooks/stable-diffusion-webui-forge/models/Lora
# --2024-04-03 12:59:46--  https://civitai.com/api/download/models/54280
# Resolving civitai.com (civitai.com)... 104.18.22.206, 104.18.23.206, 2606:4700::6812:16ce, ...
# Connecting to civitai.com (civitai.com)|104.18.22.206|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/124387/model/attireHotlimit10.cCGc.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22attire_hotlimit-10.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T125947Z&X-Amz-SignedHeaders=host&X-Amz-Signature=5bdc64adb43378aba74201a44b3eabe1777da94be9f2ea1a54d3aa3b4b1e8b64 [following]
# --2024-04-03 12:59:47--  https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/124387/model/attireHotlimit10.cCGc.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22attire_hotlimit-10.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20240403/us-east-1/s3/aws4_request&X-Amz-Date=20240403T125947Z&X-Amz-SignedHeaders=host&X-Amz-Signature=5bdc64adb43378aba74201a44b3eabe1777da94be9f2ea1a54d3aa3b4b1e8b64
# Resolving civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)... 104.18.8.90, 104.18.9.90, 2606:4700::6812:95a, ...
# Connecting to civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com (civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com)|104.18.8.90|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37878469 (36M) [application/octet-stream]
# Saving to: ‘attire_hotlimit-10.safetensors’
#
# attire_hotlimit-10. 100%[===================>]  36.12M   122MB/s    in 0.3s
#
# 2024-04-03 12:59:48 (122 MB/s) - ‘attire_hotlimit-10.safetensors’ saved [37878469/37878469]

# %%
#(4) forgeアップデート（アップデートが必要な時のみ実行）
# %cd /notebooks/stable-diffusion-webui-forge
# !git checkout master
# !git pull
